# %%
from torchsummary import summary

# %%
from generator import Generator

# %%
model = Generator()
model.to('cuda')
# Out:
# Generator(
#   (encoder1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (encoder2): EncoderBlock(
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (encoder3): EncoderBlock(
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (encoder4): EncoderBlock(
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (conv): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (encoder5): EncoderBlock(
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
# ...

# %%
summary(model,(3,256,256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 128, 128]           3,136
#          LeakyReLU-2         [-1, 64, 128, 128]               0
#             Conv2d-3          [-1, 128, 64, 64]         131,200
#        BatchNorm2d-4          [-1, 128, 64, 64]             256
#       EncoderBlock-5          [-1, 128, 64, 64]               0
#          LeakyReLU-6          [-1, 128, 64, 64]               0
#             Conv2d-7          [-1, 256, 32, 32]         524,544
#        BatchNorm2d-8          [-1, 256, 32, 32]             512
#       EncoderBlock-9          [-1, 256, 32, 32]               0
#         LeakyReLU-10          [-1, 256, 32, 32]               0
#            Conv2d-11          [-1, 512, 16, 16]       2,097,664
#       BatchNorm2d-12          [-1, 512, 16, 16]           1,024
#      EncoderBlock-13          [-1, 512, 16, 16]               0
# ...

# %%
from generator2 import Generator

# %%
model = Generator()
model.to('cuda')
summary(model,(3,64,64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           3,136
#          LeakyReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3          [-1, 128, 16, 16]         131,200
#        BatchNorm2d-4          [-1, 128, 16, 16]             256
#       EncoderBlock-5          [-1, 128, 16, 16]               0
#          LeakyReLU-6          [-1, 128, 16, 16]               0
#             Conv2d-7            [-1, 256, 8, 8]         524,544
#        BatchNorm2d-8            [-1, 256, 8, 8]             512
#       EncoderBlock-9            [-1, 256, 8, 8]               0
#         LeakyReLU-10            [-1, 256, 8, 8]               0
#            Conv2d-11            [-1, 512, 4, 4]       2,097,664
#       BatchNorm2d-12            [-1, 512, 4, 4]           1,024
#      EncoderBlock-13            [-1, 512, 4, 4]               0
# ...

# %%
from generator2 import UnetGenerator

model = UnetGenerator()
model.to('cuda')
summary(model,(3,64,64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           3,136
#          LeakyReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3          [-1, 128, 16, 16]         131,200
#        BatchNorm2d-4          [-1, 128, 16, 16]             256
#       EncoderBlock-5          [-1, 128, 16, 16]               0
#          LeakyReLU-6          [-1, 128, 16, 16]               0
#             Conv2d-7            [-1, 256, 8, 8]         524,544
#        BatchNorm2d-8            [-1, 256, 8, 8]             512
#       EncoderBlock-9            [-1, 256, 8, 8]               0
#         LeakyReLU-10            [-1, 256, 8, 8]               0
#            Conv2d-11            [-1, 512, 4, 4]       2,097,664
#       BatchNorm2d-12            [-1, 512, 4, 4]           1,024
#      EncoderBlock-13            [-1, 512, 4, 4]               0
# ...

# %%
from discriminator2 import ConditionalDiscriminator

model = ConditionalDiscriminator()
model.to('cuda')
summary(model,[(3,64,64),(3,64,64)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           6,208
#          LeakyReLU-2           [-1, 64, 32, 32]               0
#         BasicBlock-3           [-1, 64, 32, 32]               0
#             Conv2d-4          [-1, 128, 16, 16]         131,200
#     InstanceNorm2d-5          [-1, 128, 16, 16]               0
#          LeakyReLU-6          [-1, 128, 16, 16]               0
#         BasicBlock-7          [-1, 128, 16, 16]               0
#             Conv2d-8            [-1, 256, 8, 8]         524,544
#     InstanceNorm2d-9            [-1, 256, 8, 8]               0
#         LeakyReLU-10            [-1, 256, 8, 8]               0
#        BasicBlock-11            [-1, 256, 8, 8]               0
#            Conv2d-12            [-1, 512, 4, 4]       2,097,664
#    InstanceNorm2d-13            [-1, 512, 4, 4]               0
# ...

# %%
from discriminator2 import ConditionalDiscriminator

model = ConditionalDiscriminator()
model.to('cuda')
summary(model,[(3,64,64),(3,64,64)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           6,208
#          LeakyReLU-2           [-1, 64, 32, 32]               0
#         BasicBlock-3           [-1, 64, 32, 32]               0
#             Conv2d-4          [-1, 256, 16, 16]         262,400
#     InstanceNorm2d-5          [-1, 256, 16, 16]               0
#          LeakyReLU-6          [-1, 256, 16, 16]               0
#         BasicBlock-7          [-1, 256, 16, 16]               0
#             Conv2d-8            [-1, 512, 8, 8]       2,097,664
#     InstanceNorm2d-9            [-1, 512, 8, 8]               0
#         LeakyReLU-10            [-1, 512, 8, 8]               0
#        BasicBlock-11            [-1, 512, 8, 8]               0
#            Conv2d-12              [-1, 1, 7, 7]           8,193
# ...
# Total params: 2,374,465
# Trainable params: 2,374,465
# ...

# %%
from torchsummary import summary
